# %%
import pandas as pd
import matplotlib.pyplot as plt 
import numpy as np
import seaborn as sns

df = pd.read_csv("Reviews.csv")
print("Shape:", df.shape)
print("\n", df.columns.tolist())
print("\n")
df.head(1)
# Out:
# Shape: (568454, 10)
#
#  ['Id', 'ProductId', 'UserId', 'ProfileName', 'HelpfulnessNumerator', 'HelpfulnessDenominator', 'Score', 'Time', 'Summary', 'Text']
#    Id   ProductId          UserId ProfileName  HelpfulnessNumerator  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW  delmartian                     1
#
#    HelpfulnessDenominator  Score        Time                Summary  \
# 0                       1      5  1303862400  Good Quality Dog Food
#
#                                                 Text
# 0  I have bought several of the Vitality canned d...

# %%
print(df.dtypes)
print("\n nul values:")
print(df.isnull().sum())
print(df["Text"].iloc[0])
print("\n hey")
print(df['Score'].value_counts().sort_index())
# Out:
# Id                         int64
# ProductId                 object
# UserId                    object
# ProfileName               object
# HelpfulnessNumerator       int64
# HelpfulnessDenominator     int64
# Score                      int64
# Time                       int64
# Summary                   object
# Text                      object
# dtype: object
#
#  nul values:
# Id                         0
# ProductId                  0
# UserId                     0
# ProfileName               26
# HelpfulnessNumerator       0
# HelpfulnessDenominator     0
# Score                      0
# Time                       0
# Summary                   27
# Text                       0
# dtype: int64
# I have bought several of the Vitality canned dog food products and have found them all to be of good quality. The product looks more like a stew than a processed meat and it smells better. My Labrador is finicky and she appreciates this product better than  most.
#
#  hey
# Score
# ...

# %%
df['is_fake']=(
    (df['Score'].isin([1,5])) & 
    (df['ProfileName'].str.len()<10)).astype(int)
# df.head(10)
print(df['is_fake'].dtype)
print(df['is_fake'].value_counts())
print(f"\nFake rate: {df['is_fake'].mean():.2%}")
# print("\nFake rate: ", df['is_fake'].mean()*100,'%')
# Out:
# int64
# is_fake
# 0    407418
# 1    161036
# Name: count, dtype: int64
#
# Fake rate: 28.33%

# %%
df_sample= df.head(50000).copy()
df_sample.to_csv('Data_clean.csv', index = False)
